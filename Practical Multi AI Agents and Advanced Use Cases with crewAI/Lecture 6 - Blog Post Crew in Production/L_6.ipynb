# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 207 packages in 1.79s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# pydantic   ------------------------------     0 B/433.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# rpds-py    ------------------------------     0 B/380.31 KiB
# pydantic   ------------------------------     0 B/433.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# rpds-py    ------------------------------     0 B/380.31 KiB
# pydantic   ------------------------------     0 B/433.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# langsmith  ------------------------------     0 B/350.49 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# rpds-py    ------------------------------     0 B/380.31 KiB
# pydantic   ------------------------------     0 B/433.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# langsmith  ------------------------------     0 B/350.49 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# rpds-py    ------------------------------     0 B/380.31 KiB
# pydantic   ------------------------------     0 B/433.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------     0 B/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# langsmith  ------------------------------     0 B/350.49 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# rpds-py    ------------------------------     0 B/380.31 KiB
# pydantic   ------------------------------     0 B/433.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# cryptography ------------------------------ 14.88 KiB/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# langsmith  ------------------------------     0 B/350.49 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# rpds-py    ------------------------------     0 B/380.31 KiB
# pydantic   ------------------------------     0 B/433.19 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/570.24 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------ 14.88 KiB/1.50 MiB
# cryptography ------------------------------ 14.88 KiB/4.00 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 75.94 KiB/349.71 KiB
# langsmith  ------------------------------ 23.74 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/378.72 KiB
# rpds-py    ------------------------------ 75.26 KiB/380.31 KiB
# langchain-core ------------------------------ 14.92 KiB/426.97 KiB
# pydantic   ------------------------------ 30.92 KiB/433.19 KiB
# watchfiles ------------------------------ 16.00 KiB/444.09 KiB
# httptools  ------------------------------ 16.00 KiB/449.01 KiB
# cffi       ------------------------------ 78.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 46.88 KiB/470.15 KiB
# pytz       ------------------------------ 15.89 KiB/496.10 KiB
# mpmath     ------------------------------ 75.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 8.74 KiB/559.85 KiB
# greenlet   ------------------------------ 46.81 KiB/570.24 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# openai     ------------------------------ 32.00 KiB/645.70 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 78.81 KiB/774.15 KiB
# ipython    ------------------------------ 16.00 KiB/811.41 KiB
# langchain  ------------------------------ 16.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 123.94 KiB/349.71 KiB
# langsmith  ------------------------------ 23.74 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 46.88 KiB/378.72 KiB
# rpds-py    ------------------------------ 123.26 KiB/380.31 KiB
# langchain-core ------------------------------ 30.92 KiB/426.97 KiB
# pydantic   ------------------------------ 30.92 KiB/433.19 KiB
# watchfiles ------------------------------ 16.00 KiB/444.09 KiB
# httptools  ------------------------------ 16.00 KiB/449.01 KiB
# cffi       ------------------------------ 126.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 46.88 KiB/470.15 KiB
# pytz       ------------------------------ 31.89 KiB/496.10 KiB
# mpmath     ------------------------------ 123.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 8.74 KiB/559.85 KiB
# greenlet   ------------------------------ 46.81 KiB/570.24 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# openai     ------------------------------ 32.00 KiB/645.70 KiB
# pyvis      ------------------------------ 23.86 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 94.91 KiB/774.15 KiB
# ipython    ------------------------------ 16.00 KiB/811.41 KiB
# langchain  ------------------------------ 16.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 123.94 KiB/349.71 KiB
# langsmith  ------------------------------ 23.74 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 46.88 KiB/378.72 KiB
# rpds-py    ------------------------------ 123.26 KiB/380.31 KiB
# langchain-core ------------------------------ 30.92 KiB/426.97 KiB
# pydantic   ------------------------------ 30.92 KiB/433.19 KiB
# watchfiles ------------------------------ 16.00 KiB/444.09 KiB
# httptools  ------------------------------ 16.00 KiB/449.01 KiB
# cffi       ------------------------------ 126.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 46.88 KiB/470.15 KiB
# pytz       ------------------------------ 31.89 KiB/496.10 KiB
# mpmath     ------------------------------ 123.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 8.74 KiB/559.85 KiB
# greenlet   ------------------------------ 46.81 KiB/570.24 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# openai     ------------------------------ 32.00 KiB/645.70 KiB
# pyvis      ------------------------------ 23.86 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 94.91 KiB/774.15 KiB
# ipython    ------------------------------ 16.00 KiB/811.41 KiB
# langchain  ------------------------------ 16.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 219.94 KiB/349.71 KiB
# langsmith  ------------------------------ 55.74 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 62.88 KiB/378.72 KiB
# rpds-py    ------------------------------ 203.26 KiB/380.31 KiB
# langchain-core ------------------------------ 30.92 KiB/426.97 KiB
# pydantic   ------------------------------ 62.92 KiB/433.19 KiB
# watchfiles ------------------------------ 187.41 KiB/444.09 KiB
# httptools  ------------------------------ 167.16 KiB/449.01 KiB
# cffi       ------------------------------ 206.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 78.41 KiB/470.15 KiB
# pytz       ------------------------------ 31.89 KiB/496.10 KiB
# mpmath     ------------------------------ 155.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 24.74 KiB/559.85 KiB
# greenlet   ------------------------------ 190.81 KiB/570.24 KiB
# chromadb   ------------------------------ 62.92 KiB/613.62 KiB
# openai     ------------------------------ 48.00 KiB/645.70 KiB
# pyvis      ------------------------------ 196.48 KiB/738.32 KiB
# pyyaml     ------------------------------ 205.93 KiB/745.07 KiB
# regex      ------------------------------ 190.91 KiB/774.15 KiB
# ipython    ------------------------------ 62.88 KiB/811.41 KiB
# langchain  ------------------------------ 16.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# yarl       ------------------------------ 271.94 KiB/349.71 KiB
# langsmith  ------------------------------ 142.89 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 91.82 KiB/378.72 KiB
# rpds-py    ------------------------------ 287.26 KiB/380.31 KiB
# langchain-core ------------------------------ 62.92 KiB/426.97 KiB
# pydantic   ------------------------------ 156.23 KiB/433.19 KiB
# watchfiles ------------------------------ 252.58 KiB/444.09 KiB
# httptools  ------------------------------ 253.36 KiB/449.01 KiB
# cffi       ------------------------------ 302.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 222.62 KiB/470.15 KiB
# pytz       ------------------------------ 47.89 KiB/496.10 KiB
# mpmath     ------------------------------ 235.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 24.74 KiB/559.85 KiB
# greenlet   ------------------------------ 268.88 KiB/570.24 KiB
# chromadb   ------------------------------ 78.92 KiB/613.62 KiB
# openai     ------------------------------ 53.95 KiB/645.70 KiB
# pyvis      ------------------------------ 270.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 285.93 KiB/745.07 KiB
# regex      ------------------------------ 270.81 KiB/774.15 KiB
# ipython    ------------------------------ 110.88 KiB/811.41 KiB
# langchain  ------------------------------ 32.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# yarl       ------------------------------ 349.71 KiB/349.71 KiB
# langsmith  ------------------------------ 334.07 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 107.82 KiB/378.72 KiB
# rpds-py    ------------------------------ 367.26 KiB/380.31 KiB
# langchain-core ------------------------------ 78.92 KiB/426.97 KiB
# pydantic   ------------------------------ 236.23 KiB/433.19 KiB
# watchfiles ------------------------------ 332.58 KiB/444.09 KiB
# httptools  ------------------------------ 349.36 KiB/449.01 KiB
# cffi       ------------------------------ 382.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 282.67 KiB/470.15 KiB
# pytz       ------------------------------ 47.89 KiB/496.10 KiB
# mpmath     ------------------------------ 351.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 40.74 KiB/559.85 KiB
# greenlet   ------------------------------ 350.92 KiB/570.24 KiB
# chromadb   ------------------------------ 102.17 KiB/613.62 KiB
# openai     ------------------------------ 77.05 KiB/645.70 KiB
# pyvis      ------------------------------ 366.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 381.93 KiB/745.07 KiB
# regex      ------------------------------ 350.91 KiB/774.15 KiB
# ipython    ------------------------------ 238.88 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# yarl       ------------------------------ 349.71 KiB/349.71 KiB
# langsmith  ------------------------------ 350.07 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 107.82 KiB/378.72 KiB
# langchain-core ------------------------------ 78.92 KiB/426.97 KiB
# pydantic   ------------------------------ 236.23 KiB/433.19 KiB
# watchfiles ------------------------------ 348.58 KiB/444.09 KiB
# httptools  ------------------------------ 365.36 KiB/449.01 KiB
# cffi       ------------------------------ 382.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 314.67 KiB/470.15 KiB
# pytz       ------------------------------ 62.73 KiB/496.10 KiB
# mpmath     ------------------------------ 367.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 40.74 KiB/559.85 KiB
# greenlet   ------------------------------ 350.92 KiB/570.24 KiB
# chromadb   ------------------------------ 286.92 KiB/613.62 KiB
# openai     ------------------------------ 77.05 KiB/645.70 KiB
# pyvis      ------------------------------ 382.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 396.91 KiB/745.07 KiB
# regex      ------------------------------ 350.91 KiB/774.15 KiB
# ipython    ------------------------------ 250.12 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 280.69 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# langsmith  ------------------------------ 350.07 KiB/350.49 KiB
# prompt-toolkit ------------------------------ 123.82 KiB/378.72 KiB
# langchain-core ------------------------------ 94.92 KiB/426.97 KiB
# pydantic   ------------------------------ 252.23 KiB/433.19 KiB
# watchfiles ------------------------------ 380.58 KiB/444.09 KiB
# httptools  ------------------------------ 381.36 KiB/449.01 KiB
# cffi       ------------------------------ 414.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 318.41 KiB/470.15 KiB
# pytz       ------------------------------ 62.73 KiB/496.10 KiB
# mpmath     ------------------------------ 389.46 KiB/523.63 KiB
# crewai-tools ------------------------------ 56.74 KiB/559.85 KiB
# greenlet   ------------------------------ 392.56 KiB/570.24 KiB
# chromadb   ------------------------------ 286.92 KiB/613.62 KiB
# openai     ------------------------------ 77.05 KiB/645.70 KiB
# pyvis      ------------------------------ 382.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 397.93 KiB/745.07 KiB
# regex      ------------------------------ 392.56 KiB/774.15 KiB
# ipython    ------------------------------ 250.12 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 313.81 KiB/1.14 MiB
# pygments   ------------------------------ 334.31 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# tzdata     ------------------------------     0 B/339.69 KiB
# prompt-toolkit ------------------------------ 123.82 KiB/378.72 KiB
# langchain-core ------------------------------ 94.92 KiB/426.97 KiB
# pydantic   ------------------------------ 252.23 KiB/433.19 KiB
# watchfiles ------------------------------ 396.48 KiB/444.09 KiB
# httptools  ------------------------------ 397.36 KiB/449.01 KiB
# cffi       ------------------------------ 414.66 KiB/456.29 KiB
# huggingface-hub ------------------------------ 333.69 KiB/470.15 KiB
# pytz       ------------------------------ 62.73 KiB/496.10 KiB
# mpmath     ------------------------------ 399.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 56.74 KiB/559.85 KiB
# greenlet   ------------------------------ 392.56 KiB/570.24 KiB
# chromadb   ------------------------------ 286.92 KiB/613.62 KiB
# openai     ------------------------------ 77.05 KiB/645.70 KiB
# pyvis      ------------------------------ 398.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 413.93 KiB/745.07 KiB
# regex      ------------------------------ 392.56 KiB/774.15 KiB
# ipython    ------------------------------ 254.88 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 313.81 KiB/1.14 MiB
# pygments   ------------------------------ 334.31 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# qdrant-client ------------------------------ 15.89 KiB/320.01 KiB
# jiter      ------------------------------ 16.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 139.82 KiB/378.72 KiB
# langchain-core ------------------------------ 126.81 KiB/426.97 KiB
# pydantic   ------------------------------ 286.18 KiB/433.19 KiB
# watchfiles ------------------------------ 412.58 KiB/444.09 KiB
# httptools  ------------------------------ 432.03 KiB/449.01 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# huggingface-hub ------------------------------ 333.69 KiB/470.15 KiB
# pytz       ------------------------------ 110.73 KiB/496.10 KiB
# mpmath     ------------------------------ 415.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 56.74 KiB/559.85 KiB
# greenlet   ------------------------------ 440.56 KiB/570.24 KiB
# chromadb   ------------------------------ 286.92 KiB/613.62 KiB
# openai     ------------------------------ 92.94 KiB/645.70 KiB
# pyvis      ------------------------------ 461.92 KiB/738.32 KiB
# pyyaml     ------------------------------ 461.93 KiB/745.07 KiB
# regex      ------------------------------ 440.56 KiB/774.15 KiB
# ipython    ------------------------------ 308.41 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# qdrant-client ------------------------------ 47.17 KiB/320.01 KiB
# jiter      ------------------------------ 48.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 139.82 KiB/378.72 KiB
# langchain-core ------------------------------ 126.81 KiB/426.97 KiB
# pydantic   ------------------------------ 286.18 KiB/433.19 KiB
# watchfiles ------------------------------ 444.09 KiB/444.09 KiB
# httptools  ------------------------------ 448.03 KiB/449.01 KiB
# huggingface-hub ------------------------------ 350.41 KiB/470.15 KiB
# pytz       ------------------------------ 110.73 KiB/496.10 KiB
# mpmath     ------------------------------ 447.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 56.74 KiB/559.85 KiB
# greenlet   ------------------------------ 440.56 KiB/570.24 KiB
# chromadb   ------------------------------ 382.92 KiB/613.62 KiB
# openai     ------------------------------ 108.94 KiB/645.70 KiB
# pyvis      ------------------------------ 478.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 477.93 KiB/745.07 KiB
# regex      ------------------------------ 456.56 KiB/774.15 KiB
# ipython    ------------------------------ 334.88 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 368.06 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# qdrant-client ------------------------------ 47.17 KiB/320.01 KiB
# jiter      ------------------------------ 48.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 139.82 KiB/378.72 KiB
# langchain-core ------------------------------ 126.81 KiB/426.97 KiB
# pydantic   ------------------------------ 286.18 KiB/433.19 KiB
# httptools  ------------------------------ 448.03 KiB/449.01 KiB
# huggingface-hub ------------------------------ 350.41 KiB/470.15 KiB
# pytz       ------------------------------ 110.73 KiB/496.10 KiB
# mpmath     ------------------------------ 447.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 56.74 KiB/559.85 KiB
# greenlet   ------------------------------ 440.56 KiB/570.24 KiB
# chromadb   ------------------------------ 382.92 KiB/613.62 KiB
# openai     ------------------------------ 108.94 KiB/645.70 KiB
# pyvis      ------------------------------ 478.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 477.93 KiB/745.07 KiB
# regex      ------------------------------ 456.56 KiB/774.15 KiB
# ipython    ------------------------------ 334.88 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 368.06 KiB/1.14 MiB
# pygments   ------------------------------ 383.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# qdrant-client ------------------------------ 47.17 KiB/320.01 KiB
# jiter      ------------------------------ 64.00 KiB/337.45 KiB
# tzdata     ------------------------------ 16.00 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 139.82 KiB/378.72 KiB
# langchain-core ------------------------------ 142.81 KiB/426.97 KiB
# pydantic   ------------------------------ 302.18 KiB/433.19 KiB
# huggingface-hub ------------------------------ 350.41 KiB/470.15 KiB
# pytz       ------------------------------ 110.73 KiB/496.10 KiB
# mpmath     ------------------------------ 463.21 KiB/523.63 KiB
# crewai-tools ------------------------------ 72.74 KiB/559.85 KiB
# greenlet   ------------------------------ 456.56 KiB/570.24 KiB
# chromadb   ------------------------------ 382.92 KiB/613.62 KiB
# openai     ------------------------------ 108.94 KiB/645.70 KiB
# pyvis      ------------------------------ 494.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 493.93 KiB/745.07 KiB
# regex      ------------------------------ 472.56 KiB/774.15 KiB
# ipython    ------------------------------ 350.88 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 377.81 KiB/1.14 MiB
# pygments   ------------------------------ 398.31 KiB/1.17 MiB
# jedi       ------------------------------ 207.59 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# pypdf      ------------------------------ 16.00 KiB/295.22 KiB
# frozenlist ------------------------------ 24.90 KiB/306.27 KiB
# protobuf   ------------------------------ 32.00 KiB/312.18 KiB
# qdrant-client ------------------------------ 85.70 KiB/320.01 KiB
# jiter      ------------------------------ 112.00 KiB/337.45 KiB
# tzdata     ------------------------------ 32.00 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 187.82 KiB/378.72 KiB
# langchain-core ------------------------------ 174.92 KiB/426.97 KiB
# pydantic   ------------------------------ 348.23 KiB/433.19 KiB
# huggingface-hub ------------------------------ 366.41 KiB/470.15 KiB
# pytz       ------------------------------ 110.73 KiB/496.10 KiB
# mpmath     ------------------------------ 496.24 KiB/523.63 KiB
# crewai-tools ------------------------------ 104.74 KiB/559.85 KiB
# greenlet   ------------------------------ 472.56 KiB/570.24 KiB
# chromadb   ------------------------------ 398.92 KiB/613.62 KiB
# openai     ------------------------------ 141.05 KiB/645.70 KiB
# pyvis      ------------------------------ 526.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 536.57 KiB/745.07 KiB
# regex      ------------------------------ 520.56 KiB/774.15 KiB
# ipython    ------------------------------ 366.88 KiB/811.41 KiB
# langchain  ------------------------------ 48.00 KiB/987.09 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# pypdf      ------------------------------ 80.00 KiB/295.22 KiB
# frozenlist ------------------------------ 88.36 KiB/306.27 KiB
# protobuf   ------------------------------ 110.57 KiB/312.18 KiB
# qdrant-client ------------------------------ 117.70 KiB/320.01 KiB
# jiter      ------------------------------ 176.00 KiB/337.45 KiB
# tzdata     ------------------------------ 78.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 251.82 KiB/378.72 KiB
# langchain-core ------------------------------ 206.10 KiB/426.97 KiB
# pydantic   ------------------------------ 428.23 KiB/433.19 KiB
# huggingface-hub ------------------------------ 398.41 KiB/470.15 KiB
# pytz       ------------------------------ 126.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 472.74 KiB/559.85 KiB
# greenlet   ------------------------------ 504.56 KiB/570.24 KiB
# chromadb   ------------------------------ 430.92 KiB/613.62 KiB
# openai     ------------------------------ 173.05 KiB/645.70 KiB
# pyvis      ------------------------------ 567.89 KiB/738.32 KiB
# pyyaml     ------------------------------ 605.72 KiB/745.07 KiB
# regex      ------------------------------ 584.56 KiB/774.15 KiB
# ipython    ------------------------------ 419.56 KiB/811.41 KiB
# langchain  ------------------------------ 64.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 505.44 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# pypdf      ------------------------------ 80.00 KiB/295.22 KiB
# frozenlist ------------------------------ 88.36 KiB/306.27 KiB
# protobuf   ------------------------------ 110.57 KiB/312.18 KiB
# qdrant-client ------------------------------ 117.70 KiB/320.01 KiB
# jiter      ------------------------------ 176.00 KiB/337.45 KiB
# tzdata     ------------------------------ 78.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 251.82 KiB/378.72 KiB
# langchain-core ------------------------------ 206.10 KiB/426.97 KiB
# huggingface-hub ------------------------------ 414.41 KiB/470.15 KiB
# pytz       ------------------------------ 126.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 472.74 KiB/559.85 KiB
# greenlet   ------------------------------ 504.56 KiB/570.24 KiB
# chromadb   ------------------------------ 430.92 KiB/613.62 KiB
# openai     ------------------------------ 173.05 KiB/645.70 KiB
# pyvis      ------------------------------ 567.89 KiB/738.32 KiB
# pyyaml     ------------------------------ 605.72 KiB/745.07 KiB
# regex      ------------------------------ 584.56 KiB/774.15 KiB
# ipython    ------------------------------ 419.56 KiB/811.41 KiB
# langchain  ------------------------------ 64.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 505.44 KiB/1.14 MiB
# pygments   ------------------------------ 510.31 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# pypdf      ------------------------------ 96.00 KiB/295.22 KiB
# frozenlist ------------------------------ 103.65 KiB/306.27 KiB
# protobuf   ------------------------------ 126.57 KiB/312.18 KiB
# qdrant-client ------------------------------ 144.00 KiB/320.01 KiB
# jiter      ------------------------------ 208.00 KiB/337.45 KiB
# tzdata     ------------------------------ 78.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 267.82 KiB/378.72 KiB
# langchain-core ------------------------------ 254.10 KiB/426.97 KiB
# huggingface-hub ------------------------------ 414.41 KiB/470.15 KiB
# pytz       ------------------------------ 126.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 488.74 KiB/559.85 KiB
# greenlet   ------------------------------ 520.56 KiB/570.24 KiB
# chromadb   ------------------------------ 434.04 KiB/613.62 KiB
# openai     ------------------------------ 189.05 KiB/645.70 KiB
# pyvis      ------------------------------ 590.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 605.93 KiB/745.07 KiB
# regex      ------------------------------ 616.56 KiB/774.15 KiB
# ipython    ------------------------------ 435.56 KiB/811.41 KiB
# langchain  ------------------------------ 64.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 505.81 KiB/1.14 MiB
# pygments   ------------------------------ 526.31 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# crewai     ------------------------------ 55.85 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 35.77 KiB/287.63 KiB
# pypdf      ------------------------------ 168.55 KiB/295.22 KiB
# frozenlist ------------------------------ 181.17 KiB/306.27 KiB
# protobuf   ------------------------------ 222.46 KiB/312.18 KiB
# qdrant-client ------------------------------ 185.75 KiB/320.01 KiB
# jiter      ------------------------------ 288.00 KiB/337.45 KiB
# tzdata     ------------------------------ 78.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 334.55 KiB/378.72 KiB
# langchain-core ------------------------------ 334.10 KiB/426.97 KiB
# pytz       ------------------------------ 142.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 504.74 KiB/559.85 KiB
# greenlet   ------------------------------ 568.92 KiB/570.24 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# openai     ------------------------------ 237.05 KiB/645.70 KiB
# pyvis      ------------------------------ 682.68 KiB/738.32 KiB
# pyyaml     ------------------------------ 685.93 KiB/745.07 KiB
# regex      ------------------------------ 712.56 KiB/774.15 KiB
# ipython    ------------------------------ 494.88 KiB/811.41 KiB
# langchain  ------------------------------ 96.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 585.81 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# crewai     ------------------------------ 55.85 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 35.77 KiB/287.63 KiB
# pypdf      ------------------------------ 168.55 KiB/295.22 KiB
# frozenlist ------------------------------ 181.17 KiB/306.27 KiB
# protobuf   ------------------------------ 222.46 KiB/312.18 KiB
# qdrant-client ------------------------------ 185.75 KiB/320.01 KiB
# jiter      ------------------------------ 288.00 KiB/337.45 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 334.55 KiB/378.72 KiB
# langchain-core ------------------------------ 334.10 KiB/426.97 KiB
# pytz       ------------------------------ 142.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 504.74 KiB/559.85 KiB
# greenlet   ------------------------------ 568.92 KiB/570.24 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# openai     ------------------------------ 237.05 KiB/645.70 KiB
# pyvis      ------------------------------ 682.68 KiB/738.32 KiB
# pyyaml     ------------------------------ 685.93 KiB/745.07 KiB
# regex      ------------------------------ 712.56 KiB/774.15 KiB
# ipython    ------------------------------ 494.88 KiB/811.41 KiB
# langchain  ------------------------------ 96.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 585.81 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# crewai     ------------------------------ 55.85 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 51.77 KiB/287.63 KiB
# pypdf      ------------------------------ 192.00 KiB/295.22 KiB
# frozenlist ------------------------------ 200.47 KiB/306.27 KiB
# protobuf   ------------------------------ 237.42 KiB/312.18 KiB
# qdrant-client ------------------------------ 208.00 KiB/320.01 KiB
# jiter      ------------------------------ 304.00 KiB/337.45 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 351.82 KiB/378.72 KiB
# langchain-core ------------------------------ 350.10 KiB/426.97 KiB
# pytz       ------------------------------ 142.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 504.74 KiB/559.85 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# openai     ------------------------------ 252.83 KiB/645.70 KiB
# pyvis      ------------------------------ 714.68 KiB/738.32 KiB
# pyyaml     ------------------------------ 717.93 KiB/745.07 KiB
# regex      ------------------------------ 728.56 KiB/774.15 KiB
# ipython    ------------------------------ 510.88 KiB/811.41 KiB
# langchain  ------------------------------ 96.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 617.71 KiB/1.14 MiB
# pygments   ------------------------------ 639.73 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# cohere     ------------------------------     0 B/253.44 KiB
# bcrypt     ------------------------------ 16.00 KiB/277.50 KiB
# crewai     ------------------------------ 63.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 51.77 KiB/287.63 KiB
# pypdf      ------------------------------ 224.00 KiB/295.22 KiB
# frozenlist ------------------------------ 227.57 KiB/306.27 KiB
# protobuf   ------------------------------ 253.42 KiB/312.18 KiB
# qdrant-client ------------------------------ 224.00 KiB/320.01 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 367.72 KiB/378.72 KiB
# langchain-core ------------------------------ 368.50 KiB/426.97 KiB
# pytz       ------------------------------ 142.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 514.68 KiB/559.85 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# openai     ------------------------------ 269.05 KiB/645.70 KiB
# pyvis      ------------------------------ 734.02 KiB/738.32 KiB
# regex      ------------------------------ 774.15 KiB/774.15 KiB
# ipython    ------------------------------ 574.88 KiB/811.41 KiB
# langchain  ------------------------------ 112.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 633.81 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# cohere     ------------------------------     0 B/253.44 KiB
# bcrypt     ------------------------------ 32.00 KiB/277.50 KiB
# crewai     ------------------------------ 79.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 62.67 KiB/287.63 KiB
# pypdf      ------------------------------ 224.00 KiB/295.22 KiB
# frozenlist ------------------------------ 227.57 KiB/306.27 KiB
# protobuf   ------------------------------ 253.42 KiB/312.18 KiB
# qdrant-client ------------------------------ 240.00 KiB/320.01 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 367.72 KiB/378.72 KiB
# langchain-core ------------------------------ 368.50 KiB/426.97 KiB
# pytz       ------------------------------ 142.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 514.68 KiB/559.85 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# openai     ------------------------------ 269.05 KiB/645.70 KiB
# pyvis      ------------------------------ 734.02 KiB/738.32 KiB
# ipython    ------------------------------ 574.88 KiB/811.41 KiB
# langchain  ------------------------------ 112.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 633.81 KiB/1.14 MiB
# pygments   ------------------------------ 659.04 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# cohere     ------------------------------     0 B/253.44 KiB
# bcrypt     ------------------------------ 32.00 KiB/277.50 KiB
# crewai     ------------------------------ 79.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 62.67 KiB/287.63 KiB
# pypdf      ------------------------------ 240.00 KiB/295.22 KiB
# frozenlist ------------------------------ 243.57 KiB/306.27 KiB
# protobuf   ------------------------------ 253.42 KiB/312.18 KiB
# qdrant-client ------------------------------ 240.00 KiB/320.01 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 367.72 KiB/378.72 KiB
# langchain-core ------------------------------ 368.50 KiB/426.97 KiB
# pytz       ------------------------------ 142.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 514.68 KiB/559.85 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# openai     ------------------------------ 269.05 KiB/645.70 KiB
# pyvis      ------------------------------ 734.02 KiB/738.32 KiB
# ipython    ------------------------------ 574.88 KiB/811.41 KiB
# langchain  ------------------------------ 112.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 649.81 KiB/1.14 MiB
# pygments   ------------------------------ 659.04 KiB/1.17 MiB
# jedi       ------------------------------ 271.59 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# rich       ------------------------------     0 B/236.74 KiB
# openpyxl   ------------------------------     0 B/245.03 KiB
# cohere     ------------------------------ 16.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 48.00 KiB/277.50 KiB
# crewai     ------------------------------ 79.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 78.67 KiB/287.63 KiB
# pypdf      ------------------------------ 240.00 KiB/295.22 KiB
# frozenlist ------------------------------ 248.47 KiB/306.27 KiB
# protobuf   ------------------------------ 270.57 KiB/312.18 KiB
# qdrant-client ------------------------------ 240.00 KiB/320.01 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# langchain-core ------------------------------ 368.50 KiB/426.97 KiB
# pytz       ------------------------------ 142.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 520.74 KiB/559.85 KiB
# chromadb   ------------------------------ 494.81 KiB/613.62 KiB
# openai     ------------------------------ 269.05 KiB/645.70 KiB
# pyvis      ------------------------------ 737.88 KiB/738.32 KiB
# ipython    ------------------------------ 574.88 KiB/811.41 KiB
# langchain  ------------------------------ 112.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 665.81 KiB/1.14 MiB
# pygments   ------------------------------ 686.31 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# tomli      ------------------------------     0 B/230.50 KiB
# rich       ------------------------------     0 B/236.74 KiB
# openpyxl   ------------------------------     0 B/245.03 KiB
# cohere     ------------------------------ 32.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 61.16 KiB/277.50 KiB
# crewai     ------------------------------ 79.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 78.67 KiB/287.63 KiB
# pypdf      ------------------------------ 240.00 KiB/295.22 KiB
# frozenlist ------------------------------ 248.47 KiB/306.27 KiB
# protobuf   ------------------------------ 286.57 KiB/312.18 KiB
# qdrant-client ------------------------------ 240.00 KiB/320.01 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# langchain-core ------------------------------ 384.50 KiB/426.97 KiB
# pytz       ------------------------------ 158.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 536.63 KiB/559.85 KiB
# chromadb   ------------------------------ 494.81 KiB/613.62 KiB
# openai     ------------------------------ 269.05 KiB/645.70 KiB
# ipython    ------------------------------ 574.88 KiB/811.41 KiB
# langchain  ------------------------------ 112.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 665.81 KiB/1.14 MiB
# pygments   ------------------------------ 734.31 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# tomli      ------------------------------     0 B/230.50 KiB
# rich       ------------------------------ 16.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# cohere     ------------------------------ 32.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 61.16 KiB/277.50 KiB
# crewai     ------------------------------ 79.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 78.67 KiB/287.63 KiB
# pypdf      ------------------------------ 240.00 KiB/295.22 KiB
# frozenlist ------------------------------ 264.47 KiB/306.27 KiB
# protobuf   ------------------------------ 286.57 KiB/312.18 KiB
# qdrant-client ------------------------------ 240.00 KiB/320.01 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# langchain-core ------------------------------ 384.50 KiB/426.97 KiB
# pytz       ------------------------------ 158.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 536.63 KiB/559.85 KiB
# chromadb   ------------------------------ 494.81 KiB/613.62 KiB
# openai     ------------------------------ 269.05 KiB/645.70 KiB
# ipython    ------------------------------ 590.88 KiB/811.41 KiB
# langchain  ------------------------------ 112.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 681.81 KiB/1.14 MiB
# pygments   ------------------------------ 750.31 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# alembic    ------------------------------ 32.00 KiB/226.48 KiB
# propcache  ------------------------------ 32.62 KiB/227.05 KiB
# tomli      ------------------------------ 62.32 KiB/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# cohere     ------------------------------ 63.89 KiB/253.44 KiB
# bcrypt     ------------------------------ 125.16 KiB/277.50 KiB
# crewai     ------------------------------ 95.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 94.67 KiB/287.63 KiB
# pypdf      ------------------------------ 288.00 KiB/295.22 KiB
# frozenlist ------------------------------ 300.98 KiB/306.27 KiB
# protobuf   ------------------------------ 312.18 KiB/312.18 KiB
# qdrant-client ------------------------------ 304.00 KiB/320.01 KiB
# tzdata     ------------------------------ 94.99 KiB/339.69 KiB
# pytz       ------------------------------ 158.73 KiB/496.10 KiB
# crewai-tools ------------------------------ 536.63 KiB/559.85 KiB
# chromadb   ------------------------------ 510.81 KiB/613.62 KiB
# openai     ------------------------------ 285.05 KiB/645.70 KiB
# ipython    ------------------------------ 638.88 KiB/811.41 KiB
# langchain  ------------------------------ 128.00 KiB/987.09 KiB
# tiktoken   ------------------------------ 745.81 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/200)
# python-dateutil ------------------------------     0 B/224.50 KiB
# alembic    ------------------------------ 48.00 KiB/226.48 KiB
# propcache  ------------------------------ 64.00 KiB/227.05 KiB
# tomli      ------------------------------ 64.00 KiB/230.50 KiB
# rich       ------------------------------ 62.85 KiB/236.74 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# cohere     ------------------------------ 63.89 KiB/253.44 KiB
# bcrypt     ------------------------------ 141.16 KiB/277.50 KiB
# crewai     ------------------------------ 95.08 KiB/278.81 KiB
# googleapis-common-protos ------------------------------ 100.81 KiB/287.63 KiB
# ...
# onnxruntime ------------------------------ 14.51 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.77 MiB/16.46 MiB
# lancedb    ------------------------------ 15.53 MiB/31.40 MiB
# ⠦ Preparing packages... (194/200) 15.36 MiB/40.13 MiB
# pyright    ------------------------------ 3.07 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.51 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.77 MiB/16.46 MiB
# lancedb    ------------------------------ 15.55 MiB/31.40 MiB
# ⠦ Preparing packages... (194/200) 15.36 MiB/40.13 MiB
# pyright    ------------------------------ 3.07 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.51 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.77 MiB/16.46 MiB
# lancedb    ------------------------------ 15.56 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 15.36 MiB/40.13 MiB
# pyright    ------------------------------ 3.19 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.83 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.46 MiB
# lancedb    ------------------------------ 16.03 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 15.81 MiB/40.13 MiB
# pyright    ------------------------------ 3.19 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.83 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.46 MiB
# lancedb    ------------------------------ 16.03 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 15.84 MiB/40.13 MiB
# pyright    ------------------------------ 3.19 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.83 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.46 MiB
# lancedb    ------------------------------ 16.03 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 15.86 MiB/40.13 MiB
# pyright    ------------------------------ 3.19 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.83 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.46 MiB
# lancedb    ------------------------------ 16.03 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 15.87 MiB/40.13 MiB
# pyright    ------------------------------ 3.19 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.83 MiB/15.26 MiB
# numpy      ------------------------------ 10.06 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.46 MiB
# lancedb    ------------------------------ 16.03 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 15.89 MiB/40.13 MiB
# pyright    ------------------------------ 3.21 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.88 MiB/15.26 MiB
# numpy      ------------------------------ 12.25 MiB/15.67 MiB
# uv         ------------------------------ 15.58 MiB/16.46 MiB
# lancedb    ------------------------------ 16.59 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 16.45 MiB/40.13 MiB
# pyright    ------------------------------ 3.21 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.89 MiB/15.26 MiB
# numpy      ------------------------------ 13.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.00 MiB/31.40 MiB
# ⠧ Preparing packages... (194/200) 17.75 MiB/40.13 MiB
# pyright    ------------------------------ 3.22 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.89 MiB/15.26 MiB
# numpy      ------------------------------ 13.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.00 MiB/31.40 MiB
# ⠇ Preparing packages... (195/200) 17.83 MiB/40.13 MiB
# pyright    ------------------------------ 3.22 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.89 MiB/15.26 MiB
# numpy      ------------------------------ 13.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.00 MiB/31.40 MiB
# ⠇ Preparing packages... (195/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.22 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.06 MiB/15.26 MiB
# numpy      ------------------------------ 13.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.17 MiB/31.40 MiB
# ⠇ Preparing packages... (195/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.22 MiB/5.31 MiB
# numpy      ------------------------------ 13.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.30 MiB/31.40 MiB
# ⠇ Preparing packages... (195/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.24 MiB/5.31 MiB
# numpy      ------------------------------ 13.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.43 MiB/31.40 MiB
# ⠋ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.24 MiB/5.31 MiB
# numpy      ------------------------------ 13.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.44 MiB/31.40 MiB
# ⠋ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.24 MiB/5.31 MiB
# numpy      ------------------------------ 13.14 MiB/15.67 MiB
# lancedb    ------------------------------ 17.44 MiB/31.40 MiB
# ⠋ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.24 MiB/5.31 MiB
# numpy      ------------------------------ 13.19 MiB/15.67 MiB
# lancedb    ------------------------------ 17.44 MiB/31.40 MiB
# ⠋ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.25 MiB/5.31 MiB
# numpy      ------------------------------ 14.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.89 MiB/31.40 MiB
# ⠙ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.25 MiB/5.31 MiB
# numpy      ------------------------------ 14.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.89 MiB/31.40 MiB
# ⠙ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.27 MiB/5.31 MiB
# numpy      ------------------------------ 14.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.89 MiB/31.40 MiB
# ⠙ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.28 MiB/5.31 MiB
# numpy      ------------------------------ 14.03 MiB/15.67 MiB
# lancedb    ------------------------------ 17.89 MiB/31.40 MiB
# ⠙ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.31 MiB/5.31 MiB
# lancedb    ------------------------------ 18.95 MiB/31.40 MiB
# ⠙ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.35 MiB/5.31 MiB
# lancedb    ------------------------------ 18.95 MiB/31.40 MiB
# ⠙ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.49 MiB/5.31 MiB
# lancedb    ------------------------------ 21.91 MiB/31.40 MiB
# ⠙ Preparing packages... (196/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.82 MiB/5.31 MiB
# lancedb    ------------------------------ 22.66 MiB/31.40 MiB
# ⠸ Preparing packages... (197/200) 18.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.83 MiB/5.31 MiB
# lancedb    ------------------------------ 22.92 MiB/31.40 MiB
# ⠸ Preparing packages... (197/200) 18.38 MiB/40.13 MiB
# pyright    ------------------------------ 3.83 MiB/5.31 MiB
# lancedb    ------------------------------ 23.00 MiB/31.40 MiB
# ⠸ Preparing packages... (197/200) 18.38 MiB/40.13 MiB
# pyright    ------------------------------ 3.83 MiB/5.31 MiB
# lancedb    ------------------------------ 23.02 MiB/31.40 MiB
# ⠸ Preparing packages... (197/200) 18.38 MiB/40.13 MiB
# pyright    ------------------------------ 3.83 MiB/5.31 MiB
# lancedb    ------------------------------ 23.03 MiB/31.40 MiB
# ⠸ Preparing packages... (197/200) 18.38 MiB/40.13 MiB
# pyright    ------------------------------ 4.16 MiB/5.31 MiB
# lancedb    ------------------------------ 24.86 MiB/31.40 MiB
# ⠸ Preparing packages... (197/200) 18.38 MiB/40.13 MiB
# pyright    ------------------------------ 4.43 MiB/5.31 MiB
# lancedb    ------------------------------ 24.86 MiB/31.40 MiB
# ⠼ Preparing packages... (197/200) 18.38 MiB/40.13 MiB
# pyright    ------------------------------ 4.51 MiB/5.31 MiB
# lancedb    ------------------------------ 24.86 MiB/31.40 MiB
# ⠼ Preparing packages... (197/200) 18.84 MiB/40.13 MiB
# pyright    ------------------------------ 4.51 MiB/5.31 MiB
# lancedb    ------------------------------ 24.88 MiB/31.40 MiB
# ⠼ Preparing packages... (197/200) 18.84 MiB/40.13 MiB
# pyright    ------------------------------ 4.51 MiB/5.31 MiB
# lancedb    ------------------------------ 24.90 MiB/31.40 MiB
# ⠼ Preparing packages... (197/200) 18.84 MiB/40.13 MiB
# pyright    ------------------------------ 4.51 MiB/5.31 MiB
# lancedb    ------------------------------ 24.91 MiB/31.40 MiB
# ⠼ Preparing packages... (197/200) 18.84 MiB/40.13 MiB
# pyright    ------------------------------ 4.51 MiB/5.31 MiB
# lancedb    ------------------------------ 29.55 MiB/31.40 MiB
# ⠼ Preparing packages... (197/200) 18.84 MiB/40.13 MiB
# lancedb    ------------------------------ 31.40 MiB/31.40 MiB
# ⠼ Preparing packages... (197/200) 18.84 MiB/40.13 MiB
# ⠴ Preparing packages... (199/200) 18.84 MiB/40.13 MiB
# ⠴ Preparing packages... (199/200) 18.84 MiB/40.13 MiB
# ⠦ Preparing packages... (199/200) 20.43 MiB/40.13 MiB
# ⠦ Preparing packages... (199/200) 21.07 MiB/40.13 MiB
# ⠦ Preparing packages... (199/200) 21.19 MiB/40.13 MiB
# ⠦ Preparing packages... (199/200) 21.21 MiB/40.13 MiB
# ⠧ Preparing packages... (199/200) 21.51 MiB/40.13 MiB
# ⠧ Preparing packages... (199/200) 22.38 MiB/40.13 MiB
# ⠧ Preparing packages... (199/200) 22.42 MiB/40.13 MiB
# ⠧ Preparing packages... (199/200) 22.44 MiB/40.13 MiB
# ⠧ Preparing packages... (199/200) 26.64 MiB/40.13 MiB
# ⠧ Preparing packages... (199/200) 32.06 MiB/40.13 MiB
# ⠇ Preparing packages... (199/200) 33.09 MiB/40.13 MiB
# ⠋ Preparing packages... (199/200) 33.11 MiB/40.13 MiB
# ⠋ Preparing packages... (199/200) 34.22 MiB/40.13 MiB
# ⠋ Preparing packages... (199/200) 34.28 MiB/40.13 MiB
# ⠋ Preparing packages... (199/200) 34.30 MiB/40.13 MiB
# ⠋ Preparing packages... (199/200) 34.31 MiB/40.13 MiB
# ⠋ Preparing packages... (199/200) 36.54 MiB/40.13 MiB
# Prepared 200 packages in 8.93s
# Installed 200 packages in 265ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.11.18
#  + aiosignal==1.3.2
#  + alembic==1.15.2
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + auth0-python==4.9.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.4
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.2
#  + certifi==2025.1.31
#  + cffi==1.17.1
#  + charset-normalizer==3.4.1
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.1.8
#  + cohere==5.15.0
#  + coloredlogs==15.0.1
#  + crewai==0.114.0
#  + crewai-tools==0.40.1
#  + cryptography==44.0.2
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + durationpy==0.9
#  + embedchain==0.1.128
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.12
#  + fastavro==1.10.0
#  + filelock==3.18.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.6.0
#  + fsspec==2025.3.2
#  + google-auth==2.39.0
#  + googleapis-common-protos==1.70.0
#  + gptcache==0.1.44
#  + greenlet==3.2.1
#  + grpcio==1.72.0
#  + h11==0.16.0
#  + h2==4.2.0
#  + hpack==4.1.0
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.30.2
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.6.1
#  + importlib-resources==6.5.2
#  + instructor==1.7.9
#  + ipython==8.35.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.8.2
#  + json-repair==0.42.0
#  + json5==0.12.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.5
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2025.4.1
#  + kubernetes==32.0.1
#  + lancedb==0.21.2
#  + langchain==0.3.24
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.22
#  + langchain-core==0.3.56
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.8
#  + langsmith==0.3.34
#  + litellm==1.60.2
#  + mako==1.3.10
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.93
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.4.3
#  + mypy-extensions==1.1.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.5
#  + oauthlib==3.2.2
#  + onnxruntime==1.21.1
#  + openai==1.76.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.32.1
#  + opentelemetry-exporter-otlp-proto-common==1.32.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.32.1
#  + opentelemetry-exporter-otlp-proto-http==1.32.1
#  + opentelemetry-instrumentation==0.53b1
#  + opentelemetry-instrumentation-asgi==0.53b1
#  + opentelemetry-instrumentation-fastapi==0.53b1
#  + opentelemetry-proto==1.32.1
#  + opentelemetry-sdk==1.32.1
#  + opentelemetry-semantic-conventions==0.53b1
#  + opentelemetry-util-http==0.53b1
#  + orjson==3.10.16
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parso==0.8.4
#  + pdfminer-six==20250327
#  + pdfplumber==0.11.6
#  + pexpect==4.9.0
#  + pillow==11.2.1
#  + portalocker==2.10.1
#  + posthog==3.25.0
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.1
#  + protobuf==5.29.4
#  + psycopg2-binary==2.9.10
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==19.0.1
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.3
#  + pydantic-core==2.33.1
#  + pydantic-settings==2.9.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pypdf==5.4.0
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.400
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.0
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.14.2
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.24.0
#  + rsa==4.9.1
#  + schema==0.7.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.7
#  + sqlalchemy==2.0.40
#  + stack-data==0.6.3
#  + starlette==0.46.2
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.1.2
#  + tiktoken==0.9.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.15.2
#  + types-requests==2.32.0.20250328
#  + typing-extensions==4.13.2
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.0
#  + tzdata==2025.2
#  + urllib3==2.4.0
#  + uv==0.6.16
#  + uvicorn==0.34.2
#  + uvloop==0.21.0
#  + watchfiles==1.0.5
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.2
#  + yarl==1.20.0
#  + zipp==3.21.0
#  + zstandard==0.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: eea15b7b-4095-4659-bf81-27dd382882ca                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
#        Status: Executing Task...
#
# 🚀 Crew: crew
# └── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: In Progress
#
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
# └── 🧠 Thinking...
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Multimodal Capabilities**: AI LLMs in 2024 have increasingly adopted multimodal capabilities, allowing them to process and generate not only text but also images, audio, and video, enhancing user interactivity and expanding their application areas.
#
# 2. **Enhanced Fine-Tuning Techniques**: There has been significant improvement in fine-tuning methods, enabling LLMs to adapt to specialized tasks more efficiently while using smaller datasets. This process is often facilitated by techniques like prompt engineering and few-shot learning.
#
# 3. **Responsible AI Initiatives**: As ethical concerns surrounding AI LLMs continue to grow, many leading organizations are implementing strict guidelines and frameworks aimed at transparency, fairness, and accountability to mitigate bias and ensure responsible AI usage.
#
# 4. **Increased Energy Efficiency**: Advances in model design and training procedures have led to more energy-efficient LLMs. Researchers are focusing on optimizing architectures to accomplish lower carbon footprints while maintaining high performance levels.
#
# 5. **Human-AI Collaboration Tools**: The rise of AI literacy among professionals has fostered the development of collaboration tools that integrate LLMs into workflows across various industries, improving productivity in fields like content creation, customer support, and research.
#
# 6. **Regulatory Developments**: Governments and regulatory bodies are increasingly focusing on the implications of generative AI. Legislative frameworks are being designed to address intellectual property issues, misinformation, and the ethical deployment of LLM technologies.
#
# 7. **Open Source and Community Innovations**: The open-source community remains vibrant in 2024, with many organizations releasing cutting-edge LLMs that democratize access and encourage innovations through collaboration, fostering a collaborative environment for researchers and developers.
#
# 8. **Continuous Learning Models**: New architectures are being tested that allow LLMs to continuously learn from interactions post-deployment, enabling them to stay up-to-date with real-time information, trends, and evolving language patterns without a complete retraining.
#
# 9. **Domain-Specific Deployment**: Organizations are increasingly deploying domain-specific LLMs tailored to particular industries like healthcare, finance, and law, which enhances the model's understanding and response accuracy for industry-specific jargon and nuances.
#
# 10. **User-Centric Development**: The design and deployment of LLMs are increasingly user-focused, with features that enable customizable interaction styles, improved robustness to adversarial inputs, and greater adaptability to user preferences, ensuring a more personalized experience.
#
#
# 🚀 Crew: crew
# └── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# └── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
#        Assigned to: AI LLMs Senior Data Researcher
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 42cac158-604f-462d-941d-c46b8fd8d8d5
#        Status: Executing Task...
#
# 🚀 Crew: crew
# ├── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 42cac158-604f-462d-941d-c46b8fd8d8d5
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: In Progress
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Comprehensive Report on AI LLM Developments in 2024
#
# ## 1. Multimodal Capabilities
# In 2024, AI LLMs have made significant strides in adopting multimodal capabilities, a development that allows these models to process and generate diverse forms of data including text, images, audio, and video. This evolution has transformed user interactivity, enabling a richer and more engaging experience. For instance, applications can now synthesize text-based summaries of image content or generate descriptive audio for visually impaired users. Industries such as education, marketing, and gaming have benefited from these capabilities, as they enable more dynamic and versatile content creation strategies. The advancement of multimodal models means they can cater to various user needs, making them applicable in areas such as interactive storytelling, personalized learning experiences, and real-time video content analysis.
#
# ## 2. Enhanced Fine-Tuning Techniques
# The improvements in fine-tuning techniques have been remarkable, allowing AI LLMs to adapt more adeptly to specialized tasks with considerably less data. In 2024, methodologies such as prompt engineering and few-shot learning are at the forefront, enabling LLMs to optimize performance with minimal input. These techniques help the models to quickly adjust to unique contexts or niche requirements, making them suitable for specific industries without the need for extensive retraining. This enhances their utility in various applications, from legal document analysis to technical writing, where specificity is crucial. The agility afforded by these fine-tuning advancements opens doors for faster deployment and reduced operational costs for businesses leveraging AI technologies.
#
# ## 3. Responsible AI Initiatives
# As the deployment of AI LLMs proliferates, the ethical implications have garnered increased attention from researchers and practitioners. In response, many leading organizations advocate for and adopt responsible AI initiatives aimed at ensuring transparency, fairness, and accountability in the application of these technologies. Frameworks are being established to address bias mitigation, provide clearer interpretations of model decisions, and uphold ethical data usage practices. Collaborations among academic, regulatory, and industry stakeholders are being prioritized to create standards that guide the ethical deployment of AI. An emphasis on responsible AI is crucial in building public trust and promoting equitable advantages across different demographics.
#
# ## 4. Increased Energy Efficiency
# The growing awareness of climate impact has prompted researchers to focus on energy efficiency in LLMs. Advances in model architecture and training techniques have led to designs that significantly reduce energy consumption while maintaining high-performance levels. Strategies such as pruning, quantization, and more efficient training algorithms are being implemented to lower carbon footprints during model training and inference phases. These enhancements not only align with corporate sustainability goals but also improve the feasibility of deploying AI in resource-constrained environments. Organizations that prioritize energy-efficient models contribute to the broader shift toward sustainable tech development.
#
# ## 5. Human-AI Collaboration Tools
# The rise of AI literacy has spurred the creation of collaboration tools that effectively integrate LLMs into various professional workflows. Industries like content creation, customer support, and research are witnessing enhanced productivity through AI-human collaborations. For example, content creators can use LLMs to generate initial drafts, freeing them to focus on refining and personalizing output. In customer support, AI models assist agents by providing real-time information and suggested responses based on customer inquiries, thus reducing response times and improving service quality. These collaborative tools signify a shift towards humans leveraging AI as an augmentation to their capabilities rather than a replacement.
#
# ## 6. Regulatory Developments
# 2024 has seen an uptick in regulatory attention on generative AI technologies. Governments and regulatory bodies are working diligently to establish frameworks that address pivotal issues related to intellectual property, misinformation, and the ethical use of LLMs. Legislative efforts include defining responsibilities around AI-generated content and seeking to ensure accountability from organizations deploying such technologies. These initiatives aim to create a balanced framework that fosters innovation while safeguarding public interests, highlighting the ongoing dialogue about technology’s implications in society.
#
# ## 7. Open Source and Community Innovations
# The open-source community continues to flourish in 2024, with numerous organizations releasing advanced LLMs that democratize access and stimulate innovation. Initiatives that foster collaborative research and development have gained traction, enabling smaller entities and individual developers to contribute to creating cutting-edge technologies. This collaborative spirit has facilitated rapid advancements in the modeling techniques and applications of LLMs. Open-source projects also provide transparency, allowing the community to audit and improve models collectively, benefiting the ecosystem at large.
#
# ## 8. Continuous Learning Models
# Innovative architectures are being tested that allow AI LLMs to engage in continuous learning post-deployment. This capability enables the models to incorporate real-time updates, adapt to evolving language patterns, and remain relevant without requiring comprehensive retraining cycles. Continuous learning ensures that models can provide up-to-date information and maintain accuracy in their responses, essential in fast-paced environments such as news aggregation and social media monitoring. Organizations that implement continuous learning mechanisms can significantly enhance the relevance and effectiveness of LLM applications.
#
# ## 9. Domain-Specific Deployment
# A growing trend in 2024 is the deployment of domain-specific LLMs tailored for particular industries like healthcare, finance, and law. These specialized models demonstrate enhanced capabilities for interpreting jargon and comprehensively addressing industry-specific queries. By fine-tuning LLMs to understand the nuances of specialty terms and scenarios, organizations can achieve higher accuracy and efficiency in tasks such as diagnoses in healthcare or compliance in finance. This tailored approach allows for innovative applications of AI that better serve professional needs and improve overarching communication within sectors.
#
# ## 10. User-Centric Development
# The focus in developing AI LLMs is increasingly on user-centric design, emphasizing customization and adaptability. Features that allow for personalized interaction styles, resilience against adversarial inputs, and adjustments based on user preferences are becoming standard practice. This user-focused paradigm ensures a more individualized experience, making AI tools more intuitive and effective in meeting user demands. Organizations recognize that enhancing user experience leads to increased satisfaction and loyalty, thus driving better engagement with AI-powered applications.
#
# This report outlines the advancements and current trends in AI LLM technology due in 2024. As the landscape continues to evolve, stakeholders must embrace these changes to leverage AI effectively while addressing the challenges that arise.
#
#
# 🚀 Crew: crew
# ├── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 42cac158-604f-462d-941d-c46b8fd8d8d5
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# ├── 📋 Task: 6a8a5c16-8e91-4e74-bd1c-4a70a6393b96
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 42cac158-604f-462d-941d-c46b8fd8d8d5
#        Assigned to: AI LLMs Reporting Analyst
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 42cac158-604f-462d-941d-c46b8fd8d8d5                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: eea15b7b-4095-4659-bf81-27dd382882ca                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
